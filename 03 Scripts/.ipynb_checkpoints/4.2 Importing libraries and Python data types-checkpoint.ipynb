# %% [markdown]
# #01. Importing Libraries#

# %% [markdown]
# #01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #0.2 Testing Data Types

# %%
X=5

# %%
Y=10

# %%
Z=X*Y

# %%
10*Y
# Out:
# 100

# %%
20*X
# Out:
# 100

# %%
150-Z
# Out:
# 100

# %%
S= 'DATA '

# %%
A= 'Analysis'

# %%
S+A
# Out:
# 'DATA Analysis'

# %%
5*S+5*A
# Out:
# 'DATA DATA DATA DATA DATA AnalysisAnalysisAnalysisAnalysisAnalysis'
