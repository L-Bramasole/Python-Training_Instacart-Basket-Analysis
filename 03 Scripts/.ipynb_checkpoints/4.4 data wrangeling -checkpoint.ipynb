# %% [markdown]
# # Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing data

# %%
#Import DATA
orders_df = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\orders.csv', index_col = False)
product_df = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\products.csv', index_col = False)

# %%
orders_df .shape
# Out:
# (3421083, 7)

# %%
product_df.shape
# Out:
# (49693, 5)

# %%
vars_list= ['order_id', 'user_id', 'order_number', 'order_dow',
       'order_hour_of_day', 'days_since_prior_order']

# %%
#Import DATA clean
orders_df = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\orders.csv', usecols=vars_list, index_col = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Import DATA clean
# ----> 2 orders_df = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\orders.csv', usecols=vars_list, index_col = False)
#
# NameError: name 'vars_list' is not defined

# %% [markdown]
# # Wrangeling data

# %%
orders_df['days_since_prior_order'].value_counts(dropna= False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
orders_df.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
orders_df['order_id'] = orders_df['order_id'].astype('str')

# %%
orders_df['user_id'] = orders_df['user_id'].astype('str')

# %%
orders_df.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#importing departments data
dep_df= pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\departments.csv', index_col = False)

# %%
product_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
dep_df.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing departments df
dep_df.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
dep_df_t= dep_df.T

# %%
dep_df_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
dep_df_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
dep_df_t.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dep_df_t.shape
#
# NameError: name 'dep_df_t' is not defined

# %% [markdown]
# # copy the content of raw 0 as newh header to later use

# %%
NewHeader= dep_df_t.iloc[0]

# %%
# create a new df without raw 0
dep_df_t_N= dep_df_t[1:]

# %%
dep_df_t_N.reset_index()
# Out:
#    index                0
# 0      1           frozen
# 1      2            other
# 2      3           bakery
# 3      4          produce
# 4      5          alcohol
# 5      6    international
# 6      7        beverages
# 7      8             pets
# 8      9  dry goods pasta
# 9     10             bulk
# 10    11    personal care
# 11    12     meat seafood
# 12    13           pantry
# 13    14        breakfast
# 14    15     canned goods
# 15    16       dairy eggs
# 16    17        household
# 17    18           babies
# 18    19           snacks
# 19    20             deli
# 20    21          missing

# %%
NewHeader
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
dep_df_t_N.columns = NewHeader

# %%
dep_df_t_N.head()
# Out:
# department_id index department
# 0                 1     frozen
# 1                 2      other
# 2                 3     bakery
# 3                 4    produce
# 4                 5    alcohol

# %%
dep_df_t_N = dep_df_t_N.rename(columns={
    'index': 'department_id',
    'department_id': 'index'
})

# %%
dep_df_t_N.head()
# Out:
# department_id department_id department
# 0                         1     frozen
# 1                         2      other
# 2                         3     bakery
# 3                         4    produce
# 4                         5    alcohol

# %%
dep_df_t_N = dep_df_t_N.rename(columns={
    'index': 'temp_index'
})

# %%
dep_df_t_N = dep_df_t_N.rename(columns={
    'department_id': 'index',
    'temp_index': 'department_id'
})

# %%
dep_df_t_N.head()
# Out:
# department_id index department
# 0                 1     frozen
# 1                 2      other
# 2                 3     bakery
# 3                 4    produce
# 4                 5    alcohol

# %%
dep_df_t_N.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dep_df_t_N.shape
#
# NameError: name 'dep_df_t_N' is not defined

# %%
data_dict = dep_df_t_N.to_dict('index')

# %%
data_dict
# Out:
# {0: {'index': '1', 'department': 'frozen'},
#  1: {'index': '2', 'department': 'other'},
#  2: {'index': '3', 'department': 'bakery'},
#  3: {'index': '4', 'department': 'produce'},
#  4: {'index': '5', 'department': 'alcohol'},
#  5: {'index': '6', 'department': 'international'},
#  6: {'index': '7', 'department': 'beverages'},
#  7: {'index': '8', 'department': 'pets'},
#  8: {'index': '9', 'department': 'dry goods pasta'},
#  9: {'index': '10', 'department': 'bulk'},
#  10: {'index': '11', 'department': 'personal care'},
#  11: {'index': '12', 'department': 'meat seafood'},
#  12: {'index': '13', 'department': 'pantry'},
#  13: {'index': '14', 'department': 'breakfast'},
#  14: {'index': '15', 'department': 'canned goods'},
#  15: {'index': '16', 'department': 'dairy eggs'},
#  16: {'index': '17', 'department': 'household'},
#  17: {'index': '18', 'department': 'babies'},
#  18: {'index': '19', 'department': 'snacks'},
#  19: {'index': '20', 'department': 'deli'},
# ...

# %%
print(data_dict.get('19'))
# Out:
# None

# %%
print(list(data_dict.keys())[:5])  # See first few keys
print(type(list(data_dict.keys())[0]))  # Check key type
# Out:
# [0, 1, 2, 3, 4]
# <class 'int'>

# %%
dep_df_t_N_indexed = dep_df_t_N.set_index('index')
data_dict = dep_df_t_N_indexed.to_dict('index')

# %%
print(data_dict.get('19'))  # string key
# Out:
# {'department': 'snacks'}

# %% [markdown]
# * setting up snacks dataframe

# %%
snacks_df =  product_df[product_df['department_id']==19]

# %%
orders_df.to_csv(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\manipulated', 'W.orders.csv'))

# %%
snacks_df.to_csv(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\manipulated', 'W.snacks.csv'))

# %%
dep_df_t_N_indexed.to_csv(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\manipulated', 'dep_df_t_N_indexed.csv'))

# %%
dep_df_t_N_indexed=pd.read_csv(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\manipulated', 'dep_df_t_N_indexed.csv'))

# %%
dep_df_t_N_indexed.shape
# Out:
# (21, 2)

# %% [markdown]
# # Task.4.4

# %% [markdown]
# #### renaming column and type

# %%
orders_df['user_id'] = orders_df['user_id'].astype('str')

# %%
orders_df.rename(columns={'order_hour_of_day' : 'order_time'}, inplace=True)

# %% [markdown]
# #### the busiest hour for placing orders

# %%
orders_df['order_time'].value_counts(dropna=False)
# Out:
# order_time
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# #### the meaning behind a value of 4 in the "department_id" column within

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ####  breakfast item sales

# %%
breakfast_df= product_df[product_df['department_id']==14]

# %%
breakfast_df
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# #### dinner data set

# %%
Dinner_df= breakfast_df= product_df[product_df['department_id'].isin([5,7,12])]

# %%
Dinner_df
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# ###### Dinne_df has 6328 rows × 5 columns

# %% [markdown]
# #### user_id 1 subset table

# %%
user1_df= orders_df[orders_df['user_id']=='1']

# %%
user1_df
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329       1             1                   2           8
# 1   2398795       1             2                   3           7
# 2    473747       1             3                   3          12
# 3   2254736       1             4                   4           7
# 4    431534       1             5                   4          15
# 5   3367565       1             6                   2           7
# 6    550135       1             7                   1           9
# 7   3108588       1             8                   1          14
# 8   2295261       1             9                   1          16
# 9   2550362       1            10                   4           8
# 10  1187899       1            11                   4           8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# ...

# %% [markdown]
# user_id 1 has 11 orders, most orders are between 7 and 8 am. order frequency minimum evey 14 days. he order from sunday until wednesday only.

# %%
orders_df.to_csv(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\manipulated', 'W.orders.csv'))
