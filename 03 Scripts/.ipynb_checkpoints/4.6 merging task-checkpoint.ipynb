# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### importing dataframes

# %%
merged_pr_o=pd.read_pickle(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Manipulated\orders_product_Combined.pkl')

# %%
Cproducts_df=pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Manipulated\Cproducts.csv')

# %%
merged_pr_o.shape
# Out:
# (32434489, 11)

# %%
# droping the _merge column to create new one in the new merge
merged_pr_o.drop(columns=['_merge'], inplace=True)

# %%
merged_pr_o.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
Cproducts_df.shape
# Out:
# (49672, 6)

# %%
Cproducts_df.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# #### merging Cproducts with orders on product_id

# %%
or_pr_df= Cproducts_df.merge(merged_pr_o, on= ['product_id'], indicator= True)

# %%
or_pr_df.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_week  order_time  days_since_prior_order  add_to_cart_order  \
# ...

# %%
or_pr_df['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### saving the merged dataframe in new file

# %%
or_pr_df.to_pickle(os.path.join(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Manipulated\ords_prods_merge.pkl'))
