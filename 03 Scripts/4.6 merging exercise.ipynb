# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
pr_or_d = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Original\orders_products_prior.csv')

# %%
orders_df = pd.read_csv(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Manipulated\W.orders.csv')

# %%
pr_or_d.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
pr_or_d.shape
# Out:
# (32434489, 4)

# %%
orders_df.shape
# Out:
# (3421083, 7)

# %%
orders_df.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_time  days_since_prior_order
# 0           8                     NaN
# 1           7                    15.0
# 2          12                    21.0
# 3           7                    29.0
# 4          15                    28.0

# %%
merged_pr_o= orders_df.merge(pr_or_d, on = 'order_id', indicator= True)

# %%
merged_pr_o.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_time  days_since_prior_order  product_id  add_to_cart_order  \
# 0           8                     NaN         196                  1
# 1           8                     NaN       14084                  2
# 2           8                     NaN       12427                  3
# 3           8                     NaN       26088                  4
# 4           8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
merged_pr_o['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
merged_pr_o.to_pickle(r'C:\Users\analy\Documents\Instacart Basket Analysis\02 Data\Manipulated\orders_product_Combined.pkl')
